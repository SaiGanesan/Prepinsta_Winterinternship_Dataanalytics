# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import seaborn as sns
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('train.csv')

# %%
df.head(10)
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 5       6  CA-2015-115812  09/06/2015  14/06/2015  Standard Class    BH-11710
# 6       7  CA-2015-115812  09/06/2015  14/06/2015  Standard Class    BH-11710
# 7       8  CA-2015-115812  09/06/2015  14/06/2015  Standard Class    BH-11710
# 8       9  CA-2015-115812  09/06/2015  14/06/2015  Standard Class    BH-11710
# 9      10  CA-2015-115812  09/06/2015  14/06/2015  Standard Class    BH-11710
#
#      Customer Name    Segment        Country             City       State  \
# ...

# %%
df.tail()
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 9795    9796  CA-2017-125920  21/05/2017  28/05/2017  Standard Class
# 9796    9797  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9797    9798  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9798    9799  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9799    9800  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
#
#      Customer ID     Customer Name    Segment        Country     City  \
# 9795    SH-19975     Sally Hughsby  Corporate  United States  Chicago
# 9796    CS-12490  Cindy Schnelling  Corporate  United States   Toledo
# 9797    CS-12490  Cindy Schnelling  Corporate  United States   Toledo
# 9798    CS-12490  Cindy Schnelling  Corporate  United States   Toledo
# 9799    CS-12490  Cindy Schnelling  Corporate  United States   Toledo
#
#          State  Postal Code   Region       Product ID         Category  \
# ...

# %%
df.shape
# Out:
# (9800, 18)

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales
# count  9789.000000   9789.000000   9789.000000
# mean   4896.705588  55273.322403    229.525590
# std    2827.486899  32041.223413    625.278584
# min       1.000000   1040.000000      0.000000
# 25%    2449.000000  23223.000000     17.000000
# 50%    4896.000000  58103.000000     54.000000
# 75%    7344.000000  90008.000000    210.000000
# max    9800.000000  99301.000000  22638.000000

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 1          2  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 2          3  CA-2017-138688  12/06/2017  16/06/2017    Second Class
# 3          4  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 4          5  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# ...      ...             ...         ...         ...             ...
# 9795    9796  CA-2017-125920  21/05/2017  28/05/2017  Standard Class
# 9796    9797  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9797    9798  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9798    9799  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9799    9800  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
df.isna().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# dtype: int64

# %%
df.dropna(subset=['Postal Code'], inplace = True)

# %%
df.isna().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# dtype: int64

# %%
df['Postal Code'].value_counts()
# Out:
# 10035.0    253
# 10024.0    225
# 10009.0    220
# 94122.0    195
# 10011.0    193
#           ...
# 32935.0      1
# 76248.0      1
# 32127.0      1
# 32503.0      1
# 72762.0      1
# Name: Postal Code, Length: 626, dtype: int64

# %%
df['Region'].value_counts()
# Out:
# 1    3140
# 2    2774
# 3    2277
# 4    1598
# Name: Region, dtype: int64

# %%
df['Region'].replace({'West':'1','East':'2','Central':'3','South':4}, inplace = True)

# %%
df['Region'].value_counts()
# Out:
# 1    3140
# 2    2774
# 3    2277
# 4    1598
# Name: Region, dtype: int64

# %%
df['Region'] = df['Region'].astype(int)

# %%
df['Sub-Category'].value_counts()
# Out:
# Binders        1492
# Paper          1336
# Furnishings     931
# Phones          875
# Storage         831
# Art             784
# Accessories     754
# Chairs          606
# Appliances      458
# Labels          357
# Tables          314
# Envelopes       247
# Bookcases       225
# Fasteners       214
# Supplies        184
# Machines        115
# Copiers          66
# Name: Sub-Category, dtype: int64

# %%
df.nunique()
# Out:
# Row ID           9789
# Order ID         4916
# Order Date       1229
# Ship Date        1326
# Ship Mode           4
# Customer ID       793
# Customer Name     793
# Segment             3
# Country             1
# City              529
# State              48
# Postal Code       626
# Region              4
# Product ID       1860
# Category            3
# Sub-Category       17
# Product Name     1848
# Sales            1147
# dtype: int64

# %%
df['Sales'] = df['Sales'].astype(int)

# %%
sns.displot(df['Sales'])

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.ticklabel_format(style='plain')

sns.histplot(df['Sales'], kde=True)
plt.xlabel('Sales')
plt.title('Histogram Plot')
plt.show()

# %%
df.describe()
# Out:
#             Row ID   Postal Code       Region         Sales
# count  9789.000000   9789.000000  9789.000000   9789.000000
# mean   4896.705588  55273.322403     2.238329    229.525590
# std    2827.486899  32041.223413     1.072227    625.278584
# min       1.000000   1040.000000     1.000000      0.000000
# 25%    2449.000000  23223.000000     1.000000     17.000000
# 50%    4896.000000  58103.000000     2.000000     54.000000
# 75%    7344.000000  90008.000000     3.000000    210.000000
# max    9800.000000  99301.000000     4.000000  22638.000000

# %%
df['Region'].plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Sales'].plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Category'].value_counts()
# Out:
# Office Supplies    5903
# Furniture          2076
# Technology         1810
# Name: Category, dtype: int64

# %%
df['Category'].replace({'Office Supplies':'10','Furniture':'20','Technology':'30'}, inplace = True)

# %%
df['Category'].value_counts()
# Out:
# 10    5903
# 20    2076
# 30    1810
# Name: Category, dtype: int64

# %%
df['Category'] = df['Category'].astype(int)

# %% [markdown]
# 1. Univariate Analysis

# %%
sns.histplot(df['Sales'])
# Out:
# <Axes: xlabel='Sales', ylabel='Count'>

# %%
for col in df.select_dtypes(include = np.number).columns:
    print(col)
    sns.histplot(df[col])
    plt.show()
# Out:
# Row ID
# Postal Code
# Region
# Category
# Sales

# %%
for col in df.select_dtypes(include = np.number).columns:
    print(col)
    sns.boxplot(df[col])
    plt.show()
# Out:
# Row ID
# Postal Code
# Region
# Category
# Sales

# %%
for col in df.select_dtypes(include = np.number).columns:
    print(col)
    sns.countplot(df[col])
    plt.show()
# Out:
# Row ID
# Postal Code
# Region
# Category
# Sales

# %% [markdown]
# 2. Bivaraiate Analysis

# %%
df.describe()
# Out:
#             Row ID   Postal Code       Region     Category         Sales
# count  9789.000000   9789.000000  9789.000000  9789.000000   9789.000000
# mean   4896.705588  55273.322403     2.238329    15.818776    229.525590
# std    2827.486899  32041.223413     1.072227     7.830463    625.278584
# min       1.000000   1040.000000     1.000000    10.000000      0.000000
# 25%    2449.000000  23223.000000     1.000000    10.000000     17.000000
# 50%    4896.000000  58103.000000     2.000000    10.000000     54.000000
# 75%    7344.000000  90008.000000     3.000000    20.000000    210.000000
# max    9800.000000  99301.000000     4.000000    30.000000  22638.000000

# %%
sns.scatterplot(df['Region'])
# Out:
# <Axes: ylabel='Region'>

# %%
sns.pairplot(df)

# %%
df.groupby('Sub-Category')['Sales'].mean().sort_values(ascending = False).plot.bar()
# Out:
# <Axes: xlabel='Sub-Category'>

# %%
df.groupby('Region')['Sales'].mean().sort_values(ascending = False).plot.bar()
# Out:
# <Axes: xlabel='Region'>

# %%
sns.heatmap(df.select_dtypes(include = np.number).corr(), annot=True)
# Out:
# <Axes: >
